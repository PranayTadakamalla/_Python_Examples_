# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv('/content/drive/MyDrive/Day_16_Healthcare_Data.csv')
df
# Out:
#      Patient_ID  Age  Gender  Blood_Pressure  Cholesterol Diabetes  \
# 0             1   69    Male            95.0        122.0       No
# 1             2   32    Male           129.0        191.0       No
# 2             3   89  Female           101.0        214.0       No
# 3             4   78  Female           142.0        203.0       No
# 4             5   38    Male           160.0        217.0       No
# ..          ...  ...     ...             ...          ...      ...
# 500          47   25    Male           106.0        148.0       No
# 501         145   26    Male           128.0        116.0       No
# 502         213   86    Male            98.0        159.0       No
# 503         303   43    Male           171.0        243.0       No
# 504         137   79  Female           144.0        106.0       No
#
#     Heart_Disease
# 0              No
# 1              No
# 2              No
# 3              No
# 4              No
# ..            ...
# 500            No
# 501            No
# 502            No
# 503            No
# 504            No
#
# [505 rows x 7 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
df['Blood_Pressure'].fillna(df['Blood_Pressure'].median(), inplace=True)
# Out:
# <ipython-input-3-e07a2331ae2d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)
# <ipython-input-3-e07a2331ae2d>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# <ipython-input-3-e07a2331ae2d>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Blood_Pressure'].fillna(df['Blood_Pressure'].median(), inplace=True)

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns

q1 = df[numeric_cols].quantile(0.25)
q3 = df[numeric_cols].quantile(0.75)
iqr = q3 - q1

df = df[~((df[numeric_cols] < (q1 - 1.5 * iqr)) | (df[numeric_cols] > (q3 + 1.5 * iqr))).any(axis=1)]

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
scaler = MinMaxScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
df.to_csv('/content/drive/MyDrive/cleaned_healthcare_data.csv', index=False)
