# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/Day_18_Tours_and_Travels.csv"
df = pd.read_csv(file_path)
df
# Out:
#      Booking_ID Destination  Package_Price  Customer_Age  Rating  \
# 0             1      London         1094.0          21.0     NaN
# 1             2       Paris          640.0          20.0     NaN
# 2             3   Singapore         3393.0          42.0     3.0
# 3             4      London         3555.0          40.0     4.0
# 4             5       Dubai         2130.0          44.0     2.0
# ..          ...         ...            ...           ...     ...
# 500         441    New York         1600.0          64.0     3.0
# 501         487       Dubai         2875.0          66.0     4.0
# 502         432      London         2532.0          21.0     3.0
# 503         383       Dubai         1375.0          34.0     4.0
# 504         153       Paris         1391.0          18.0     1.0
#
#              Review_Text Travel_Date
# 0    Amazing experience!  2023-01-01
# 1        Loved the trip!  2023-01-02
# 2        Could be better  2023-01-03
# ...

# %%
df['Review_Text'].fillna('No Review', inplace=True)
df['Rating'].fillna(df['Rating'].median(), inplace=True)
df['Customer_Age'].fillna(df['Customer_Age'].median(), inplace=True)
df
# Out:
# <ipython-input-3-b550df30d2fa>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Review_Text'].fillna('No Review', inplace=True)
# <ipython-input-3-b550df30d2fa>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.drop_duplicates(subset=['Review_Text'], keep='first', inplace=True)
df
# Out:
#     Booking_ID Destination  Package_Price  Customer_Age  Rating  \
# 0            1      London         1094.0          21.0     3.0
# 1            2       Paris          640.0          20.0     3.0
# 2            3   Singapore         3393.0          42.0     3.0
# 4            5       Dubai         2130.0          44.0     2.0
# 15          16      London         4672.0          51.0     5.0
# 16          17   Singapore         3525.0          41.0     1.0
#
#             Review_Text Travel_Date
# 0   Amazing experience!  2023-01-01
# 1       Loved the trip!  2023-01-02
# 2       Could be better  2023-01-03
# 4    Highly recommended  2023-01-05
# 15  Not worth the money  2023-01-16
# 16            No Review  2023-01-17

# %%
print(df.columns)
# Out:
# Index(['Booking_ID', 'Destination', 'Package_Price', 'Customer_Age', 'Rating',
#        'Review_Text', 'Travel_Date'],
#       dtype='object')

# %%
df['Destination'] = df['Destination'].str.strip().str.lower()
df
# Out:
#     Booking_ID Destination  Package_Price  Customer_Age  Rating  \
# 0            1      london         1094.0          21.0     3.0
# 1            2       paris          640.0          20.0     3.0
# 2            3   singapore         3393.0          42.0     3.0
# 4            5       dubai         2130.0          44.0     2.0
# 15          16      london         4672.0          51.0     5.0
# 16          17   singapore         3525.0          41.0     1.0
#
#             Review_Text Travel_Date
# 0   Amazing experience!  2023-01-01
# 1       Loved the trip!  2023-01-02
# 2       Could be better  2023-01-03
# 4    Highly recommended  2023-01-05
# 15  Not worth the money  2023-01-16
# 16            No Review  2023-01-17

# %%
import numpy as np

q1 = df['Package_Price'].quantile(0.25)
q3 = df['Package_Price'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
df = df[(df['Package_Price'] >= lower_bound) & (df['Package_Price'] <= upper_bound)]
df
# Out:
#     Booking_ID Destination  Package_Price  Customer_Age  Rating  \
# 0            1      london         1094.0          21.0     3.0
# 1            2       paris          640.0          20.0     3.0
# 2            3   singapore         3393.0          42.0     3.0
# 4            5       dubai         2130.0          44.0     2.0
# 15          16      london         4672.0          51.0     5.0
# 16          17   singapore         3525.0          41.0     1.0
#
#             Review_Text Travel_Date
# 0   Amazing experience!  2023-01-01
# 1       Loved the trip!  2023-01-02
# 2       Could be better  2023-01-03
# 4    Highly recommended  2023-01-05
# 15  Not worth the money  2023-01-16
# 16            No Review  2023-01-17

# %%
df = pd.get_dummies(df, columns=['Destination'])
df
# Out:
#     Booking_ID  Package_Price  Customer_Age  Rating          Review_Text  \
# 0            1         1094.0          21.0     3.0  Amazing experience!
# 1            2          640.0          20.0     3.0      Loved the trip!
# 2            3         3393.0          42.0     3.0      Could be better
# 4            5         2130.0          44.0     2.0   Highly recommended
# 15          16         4672.0          51.0     5.0  Not worth the money
# 16          17         3525.0          41.0     1.0            No Review
#
#    Travel_Date  Destination_dubai  Destination_london  Destination_paris  \
# 0   2023-01-01              False                True              False
# 1   2023-01-02              False               False               True
# 2   2023-01-03              False               False              False
# 4   2023-01-05               True               False              False
# 15  2023-01-16              False                True              False
# ...

# %%
cleaned_file_path = "/content/drive/MyDrive/Cleaned_Tours_and_Travels.csv"
df.to_csv(cleaned_file_path, index=False)
